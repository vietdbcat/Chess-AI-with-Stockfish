# %%
# !pip install stockfish
from stockfish import Stockfish

# !chmod +x nhom3/stf.04-x86-64-avx2
nhom3 = Stockfish('nhom3/stf.04-x86-64-avx2', depth=37)

nhom3.set_depth(37)
nhom3.set_skill_level(20)
nhom3.get_parameters()

class Nhom3:
  def __init__(self) -> None:
    self.board = chess.Board()
  def update(self, fen):
    self.board.set_fen(fen)
  def getMove(self, fen):
    nhom3.set_fen_position(fen)
    return nhom3.get_best_move_time(2800)
